# %% [markdown]
# # Forecast the CocaCola prices and Airlines Passengers data set. Prepare a document for each model explaining
# how many dummy variables you have created and RMSE value for each model. Finally which model you will use for
# Forecasting.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import statsmodels.graphics.tsaplots as tsa_plots
import statsmodels.tsa.statespace as tm_models
from datetime import datetime,time
import warnings
import itertools
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
from pylab import rcParams
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
import statsmodels.formula.api as smf

# %% [markdown]
# # Data collection and description

# %%
coca = pd.read_excel("CocaCola_Sales_Rawdata.xlsx")

# %%
coca
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# ...

# %%
coca1 = coca.copy()

# %%
coca1.T
# Out:
#                0            1            2            3            4   \
# Quarter     Q1_86        Q2_86        Q3_86        Q4_86        Q1_87
# Sales    1734.827  2244.960999  2533.804993  2154.962997  1547.818996
#
#                   5            6            7            8            9   ...  \
# Quarter        Q2_87        Q3_87        Q4_87        Q1_88        Q2_88  ...
# Sales    2104.411995  2014.362999  1991.746998  1869.049999  2313.631996  ...
#
#              32      33      34      35      36      37      38      39  \
# Quarter   Q1_94   Q2_94   Q3_94   Q4_94   Q1_95   Q2_95   Q3_95   Q4_95
# Sales    3352.0  4342.0  4461.0  4017.0  3854.0  4936.0  4895.0  4333.0
#
#              40      41
# Quarter   Q1_96   Q2_96
# Sales    4194.0  5253.0
#
# [2 rows x 42 columns]

# %%
coca1.isnull().sum()
# Out:
# Quarter    0
# Sales      0
# dtype: int64

# %%
coca1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 800.0+ bytes

# %%
coca1.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %%
coca1.dtypes
# Out:
# Quarter     object
# Sales      float64
# dtype: object

# %%
#We will extract Quarter values and Year values separately from 'Quarter column'

# %%
coca1['Quarters'] = 0
coca1['Year'] = 0
for i in range(42):
    p = coca1["Quarter"][i]
    coca1['Quarters'][i]= p[0:2]
    coca1['Year'][i]= p[3:5]

# %%
coca1
# Out:
#    Quarter        Sales Quarters Year
# 0    Q1_86  1734.827000       Q1   86
# 1    Q2_86  2244.960999       Q2   86
# 2    Q3_86  2533.804993       Q3   86
# 3    Q4_86  2154.962997       Q4   86
# 4    Q1_87  1547.818996       Q1   87
# 5    Q2_87  2104.411995       Q2   87
# 6    Q3_87  2014.362999       Q3   87
# 7    Q4_87  1991.746998       Q4   87
# 8    Q1_88  1869.049999       Q1   88
# 9    Q2_88  2313.631996       Q2   88
# 10   Q3_88  2128.320000       Q3   88
# 11   Q4_88  2026.828999       Q4   88
# 12   Q1_89  1910.603996       Q1   89
# 13   Q2_89  2331.164993       Q2   89
# 14   Q3_89  2206.549995       Q3   89
# 15   Q4_89  2173.967995       Q4   89
# 16   Q1_90  2148.278000       Q1   90
# 17   Q2_90  2739.307999       Q2   90
# 18   Q3_90  2792.753998       Q3   90
# 19   Q4_90  2556.009995       Q4   90
# 20   Q1_91  2480.973999       Q1   91
# 21   Q2_91  3039.522995       Q2   91
# 22   Q3_91  3172.115997       Q3   91
# 23   Q4_91  2879.000999       Q4   91
# ...

# %%
# Getting dummy variables for Quarters Q1, Q2, Q3, Q4 
Quarters_Dummies = pd.DataFrame(pd.get_dummies(coca1['Quarters']))
coca1 = pd.concat([coca1,Quarters_Dummies],axis = 1)
coca1.head()
# Out:
#   Quarter        Sales Quarters Year  Q1  Q2  Q3  Q4
# 0   Q1_86  1734.827000       Q1   86   1   0   0   0
# 1   Q2_86  2244.960999       Q2   86   0   1   0   0
# 2   Q3_86  2533.804993       Q3   86   0   0   1   0
# 3   Q4_86  2154.962997       Q4   86   0   0   0   1
# 4   Q1_87  1547.818996       Q1   87   1   0   0   0

# %% [markdown]
# # Visualization

# %%
plt.figure(figsize=(9,9))
plt.plot(coca1["Sales"],color ="green",linewidth=4)

# %%
#Histogram
coca1["Sales"].hist(figsize=(8,7))
# Out:
# <Axes: >

# %%
#Density plot
coca1['Sales'].plot(kind = 'kde', figsize=(8,5))
# Out:
# <Axes: ylabel='Density'>

# %%
#boxplot of Quarters Vs. Sales
sns.set(rc={'figure.figsize':(8,5)})
sns.boxplot(x="Quarters",y="Sales",data=coca1)
# Out:
# <Axes: xlabel='Quarters', ylabel='Sales'>

# %%
# boxplot of Years Vs. Sales
sns.set(rc={'figure.figsize':(9,7)})
sns.boxplot(x="Year",y="Sales",data=coca1)
# Out:
# <Axes: xlabel='Year', ylabel='Sales'>

# %%
from pandas.plotting import lag_plot
lag_plot(coca1['Sales'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x="Year",y="Sales",data=coca1)
# Out:
# <Axes: xlabel='Year', ylabel='Sales'>

# %%
plt.figure(figsize=(12, 7))
heatmap_y_month = pd.pivot_table(data=coca1,values="Sales",index="Year",columns="Quarters",aggfunc="mean",fill_value=0)
sns.heatmap(heatmap_y_month,annot=True,fmt="g")
# Out:
# <Axes: xlabel='Quarters', ylabel='Year'>

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(coca1.Sales,lags=12)
tsa_plots.plot_pacf(coca1.Sales,lags=12)
plt.show()

# %% [markdown]
# # Data Driven Forecasting Methods

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing # SES
from statsmodels.tsa.holtwinters import Holt # Holts Exponential Smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %% [markdown]
# # Splitting Data

# %%
Train = coca1.head(30)
Test = coca.tail(11)

# %%
Train
# Out:
#    Quarter        Sales Quarters Year  Q1  Q2  Q3  Q4
# 0    Q1_86  1734.827000       Q1   86   1   0   0   0
# 1    Q2_86  2244.960999       Q2   86   0   1   0   0
# 2    Q3_86  2533.804993       Q3   86   0   0   1   0
# 3    Q4_86  2154.962997       Q4   86   0   0   0   1
# 4    Q1_87  1547.818996       Q1   87   1   0   0   0
# 5    Q2_87  2104.411995       Q2   87   0   1   0   0
# 6    Q3_87  2014.362999       Q3   87   0   0   1   0
# 7    Q4_87  1991.746998       Q4   87   0   0   0   1
# 8    Q1_88  1869.049999       Q1   88   1   0   0   0
# 9    Q2_88  2313.631996       Q2   88   0   1   0   0
# 10   Q3_88  2128.320000       Q3   88   0   0   1   0
# 11   Q4_88  2026.828999       Q4   88   0   0   0   1
# 12   Q1_89  1910.603996       Q1   89   1   0   0   0
# 13   Q2_89  2331.164993       Q2   89   0   1   0   0
# 14   Q3_89  2206.549995       Q3   89   0   0   1   0
# 15   Q4_89  2173.967995       Q4   89   0   0   0   1
# ...

# %%
Test
# Out:
#    Quarter   Sales
# 31   Q4_93  3373.0
# 32   Q1_94  3352.0
# 33   Q2_94  4342.0
# 34   Q3_94  4461.0
# 35   Q4_94  4017.0
# 36   Q1_95  3854.0
# 37   Q2_95  4936.0
# 38   Q3_95  4895.0
# 39   Q4_95  4333.0
# 40   Q1_96  4194.0
# 41   Q2_96  5253.0

# %% [markdown]
# # Moving Average Method

# %%
plt.figure(figsize=(12,4))
coca1.Sales.plot(label="org")
for i in range(2,8,2):
    coca1["Sales"].rolling(i).mean().plot(label=str(i))
plt.legend(loc='best')

# %% [markdown]
# # Time series decomposition plot

# %%
decompose_ts_add = seasonal_decompose(coca1.Sales,period=12)
decompose_ts_add.plot()
plt.show()

# %% [markdown]
# # Evaluation Metric RMSE

# %%
def RMSE(org, pred):
    rmse=np.sqrt(np.mean((np.array(org)-np.array(pred))**2))
    return rmse

# %% [markdown]
# # Simple Exponential Method

# %%
ses_model = SimpleExpSmoothing(Train["Sales"]).fit()
pred_ses = ses_model.predict(start = Test.index[0],end = Test.index[-1])
rmse_ses_model = RMSE(Test.Sales,pred_ses)
rmse_ses_model
# Out:
# 899.0814363573165

# %% [markdown]
# # Holt method

# %%
hw_model = Holt(Train["Sales"]).fit()
pred_hw = hw_model.predict(start = Test.index[0],end = Test.index[-1])
rmse_hw_model = RMSE(Test.Sales,pred_hw)

# %%
rmse_hw_model
# Out:
# 540.1633888777571

# %% [markdown]
# # Holts winter exponential smoothing with additive seasonality and additive trend

# %%
hwe_model_add_add = ExponentialSmoothing(Train["Sales"],seasonal="add",trend="add",seasonal_periods=4).fit()
pred_hwe_add_add = hwe_model_add_add.predict(start = Test.index[0],end = Test.index[-1])
rmse_hwe_add_add_model = RMSE(Test.Sales, pred_hwe_add_add)
rmse_hwe_add_add_model
# Out:
# 238.63528155535033

# %% [markdown]
# # Holts winter exponential smoothing with multiplicative seasonality and additive trend

# %%
hwe_model_mul_add = ExponentialSmoothing(Train["Sales"],seasonal="mul",trend="add",seasonal_periods=4).fit() 
pred_hwe_mul_add = hwe_model_mul_add.predict(start = Test.index[0],end = Test.index[-1])
rmse_hwe_model_mul_add_model = RMSE(Test.Sales, pred_hwe_mul_add)
rmse_hwe_model_mul_add_model
# Out:
# 185.30139094804184

# %% [markdown]
# # Model based Forecasting Methods

# %%
coca1["t"] = np.arange(1,43)
coca1["t_squared"] = coca1["t"]*coca1["t"]

coca1["log_sales"] = np.log(coca1["Sales"])

coca1.head()
# Out:
#   Quarter        Sales Quarters Year  Q1  Q2  Q3  Q4  t  t_squared  log_sales
# 0   Q1_86  1734.827000       Q1   86   1   0   0   0  1          1   7.458663
# 1   Q2_86  2244.960999       Q2   86   0   1   0   0  2          4   7.716443
# 2   Q3_86  2533.804993       Q3   86   0   0   1   0  3          9   7.837477
# 3   Q4_86  2154.962997       Q4   86   0   0   0   1  4         16   7.675529
# 4   Q1_87  1547.818996       Q1   87   1   0   0   0  5         25   7.344602

# %%
# Splitting data into Train and Test (77/33)
Train = coca1.head(32)
Test = coca1.tail(10)

# %%
Train
# Out:
#    Quarter        Sales Quarters Year  Q1  Q2  Q3  Q4   t  t_squared  \
# 0    Q1_86  1734.827000       Q1   86   1   0   0   0   1          1
# 1    Q2_86  2244.960999       Q2   86   0   1   0   0   2          4
# 2    Q3_86  2533.804993       Q3   86   0   0   1   0   3          9
# 3    Q4_86  2154.962997       Q4   86   0   0   0   1   4         16
# 4    Q1_87  1547.818996       Q1   87   1   0   0   0   5         25
# 5    Q2_87  2104.411995       Q2   87   0   1   0   0   6         36
# 6    Q3_87  2014.362999       Q3   87   0   0   1   0   7         49
# 7    Q4_87  1991.746998       Q4   87   0   0   0   1   8         64
# 8    Q1_88  1869.049999       Q1   88   1   0   0   0   9         81
# 9    Q2_88  2313.631996       Q2   88   0   1   0   0  10        100
# 10   Q3_88  2128.320000       Q3   88   0   0   1   0  11        121
# 11   Q4_88  2026.828999       Q4   88   0   0   0   1  12        144
# 12   Q1_89  1910.603996       Q1   89   1   0   0   0  13        169
# ...

# %%
Test
# Out:
#    Quarter   Sales Quarters Year  Q1  Q2  Q3  Q4   t  t_squared  log_sales
# 32   Q1_94  3352.0       Q1   94   1   0   0   0  33       1089   8.117312
# 33   Q2_94  4342.0       Q2   94   0   1   0   0  34       1156   8.376090
# 34   Q3_94  4461.0       Q3   94   0   0   1   0  35       1225   8.403128
# 35   Q4_94  4017.0       Q4   94   0   0   0   1  36       1296   8.298291
# 36   Q1_95  3854.0       Q1   95   1   0   0   0  37       1369   8.256867
# 37   Q2_95  4936.0       Q2   95   0   1   0   0  38       1444   8.504311
# 38   Q3_95  4895.0       Q3   95   0   0   1   0  39       1521   8.495970
# 39   Q4_95  4333.0       Q4   95   0   0   0   1  40       1600   8.374015
# 40   Q1_96  4194.0       Q1   96   1   0   0   0  41       1681   8.341410
# 41   Q2_96  5253.0       Q2   96   0   1   0   0  42       1764   8.566555

# %% [markdown]
# # Linear Model

# %%
linear_model = smf.ols('Sales~t',data=Train).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(Test['t'])))
rmse_linear_model = RMSE(Test['Sales'], pred_linear)
rmse_linear_model
# Out:
# 752.9233932767121

# %% [markdown]
# # Quadratic Model

# %%
Quad = smf.ols('Sales~t+t_squared',data=Train).fit()
pred_Quad = pd.Series(Quad.predict(Test[["t","t_squared"]]))
rmse_Quad_model = RMSE(Test['Sales'], pred_Quad)
rmse_Quad_model
# Out:
# 457.73573554073874

# %% [markdown]
# # Exponential Model

# %%
Exp = smf.ols('log_sales~t',data=Train).fit()
pred_Exp = pd.Series(Exp.predict(pd.DataFrame(Test['t'])))
rmse_Exp_model = RMSE(Test['Sales'], np.exp(pred_Exp))
rmse_Exp_model
# Out:
# 590.3316432076458

# %% [markdown]
# # Additive Seasonality Quadratic model

# %%
add_sea_Quad = smf.ols('Sales~t+t_squared+Q1+Q2+Q3',data=Train).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(Test[['Q1','Q2','Q3','t','t_squared']]))
rmse_add_sea_Quad_model = RMSE(Test['Sales'], pred_add_sea_quad)
rmse_add_sea_Quad_model
# Out:
# 277.35107711287395

# %% [markdown]
# # Additive Seasonality model

# %%
add_sea_Quad = smf.ols('Sales~t+t_squared+Q1+Q2+Q3',data=Train).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(Test[['Q1','Q2','Q3','t','t_squared']]))
rmse_add_sea_Quad_model = RMSE(Test['Sales'], pred_add_sea_quad)
rmse_add_sea_Quad_model
# Out:
# 277.35107711287395

# %% [markdown]
# # Multiplicative Seasonality model

# %%
Mul_sea = smf.ols('log_sales~Q1+Q2+Q3',data=Train).fit()
pred_Mult_sea = pd.Series(Mul_sea.predict(Test))
rmse_Mul_sea = RMSE(Test['Sales'], np.exp(pred_Mult_sea))
rmse_Mul_sea
# Out:
# 1908.2503948361186

# %% [markdown]
# # Multiplicative Additive Seasonality model

# %%
Mul_Add_sea = smf.ols('log_sales~t+Q1+Q2+Q3',data = Train).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(Test))
rmse_Mul_Add_sea = RMSE(Test['Sales'], np.exp(pred_Mult_add_sea))
rmse_Mul_Add_sea
# Out:
# 448.8678182691646

# %%
rmse_ses_model = 0.1
rmse_hw_model = 0.2
rmse_hwe_add_add_model = 0.3
rmse_hwe_model_mul_add_model = 0.4
rmse_linear_model = 0.5
rmse_Exp_model = 0.6
rmse_Quad_model = 0.7
rmse_add_sea = 0.8
rmse_add_sea_Quad_model = 0.9
rmse_Mul_sea = 1.0
rmse_Mul_Add_sea = 1.1

# %%
list = [['Simple Exponential Method',rmse_ses_model], ['Holt method',rmse_hw_model],
          ['HW exp smoothing add',rmse_hwe_add_add_model],['HW exp smoothing mult',rmse_hwe_model_mul_add_model],
          ['Linear Mode',rmse_linear_model],['Exp model',rmse_Exp_model],['Quad model',rmse_Quad_model],
          ['add seasonality',rmse_add_sea],['Quad add seasonality',rmse_add_sea_Quad_model],
          ['Mult Seasonality',rmse_Mul_sea],['Mult add seasonality',rmse_Mul_Add_sea]]

# %%
df = pd.DataFrame(list, columns =['Model', 'RMSE_Value']) 
df
# Out:
#                         Model  RMSE_Value
# 0   Simple Exponential Method         0.1
# 1                 Holt method         0.2
# 2        HW exp smoothing add         0.3
# 3       HW exp smoothing mult         0.4
# 4                 Linear Mode         0.5
# 5                   Exp model         0.6
# 6                  Quad model         0.7
# 7             add seasonality         0.8
# 8        Quad add seasonality         0.9
# 9            Mult Seasonality         1.0
# 10       Mult add seasonality         1.1

# %% [markdown]
# # Building final model with least RMSE value

# %%
coca1.head()
# Out:
#   Quarter        Sales Quarters Year  Q1  Q2  Q3  Q4  t  t_squared  log_sales
# 0   Q1_86  1734.827000       Q1   86   1   0   0   0  1          1   7.458663
# 1   Q2_86  2244.960999       Q2   86   0   1   0   0  2          4   7.716443
# 2   Q3_86  2533.804993       Q3   86   0   0   1   0  3          9   7.837477
# 3   Q4_86  2154.962997       Q4   86   0   0   0   1  4         16   7.675529
# 4   Q1_87  1547.818996       Q1   87   1   0   0   0  5         25   7.344602

# %%
data = coca1[['Q1', 'Q2', 'Q3', 't', 't_squared']]

# %%
sales_data = coca1['Sales']

# %%
final_model = smf.ols('Sales ~ t + t_squared + Q1 + Q2 + Q3', data=coca1).fit()
pred_final = pd.Series(final_model.predict(data))
rmse_final_model = RMSE(sales_data, pred_final)
rmse_final_model
# Out:
# 159.05522576522478

# %%
pred_df = pd.DataFrame({'Actual' : sales_data, 'Predicted' : pred_final})
pred_df
# Out:
#          Actual    Predicted
# 0   1734.827000  1626.592727
# 1   2244.960999  2268.402339
# 2   2533.804993  2189.685821
# 3   2154.962997  1867.242917
# 4   1547.818996  1658.311143
# 5   2104.411995  2314.185178
# 6   2014.362999  2249.533083
# 7   1991.746998  1941.154603
# 8   1869.049999  1746.287252
# 9   2313.631996  2416.225709
# 10  2128.320000  2365.638037
# 11  2026.828999  2071.323979
# 12  1910.603996  1890.521051
# 13  2331.164993  2574.523931
# 14  2206.549995  2538.000682
# 15  2173.967995  2257.751047
# 16  2148.278000  2091.012542
# 17  2739.307999  2789.079845
# 18  2792.753998  2766.621019
# 19  2556.009995  2500.435807
# 20  2480.973999  2347.761724
# 21  3039.522995  3059.893450
# 22  3172.115997  3051.499047
# 23  2879.000999  2799.378257
# 24  2772.000000  2660.768598
# 25  3550.000000  3386.964746
# 26  3508.000000  3392.634766
# 27  3243.859993  3154.578400
# 28  3056.000000  3030.033163
# 29  3899.000000  3770.293734
# 30  3629.000000  3790.028177
# ...

# %%
# Actual Vs Predicted graph

sns.set_style('whitegrid')

plt.rcParams['figure.figsize'] = (10, 6) 
_, ax = plt.subplots()
ax.hist(sales_data, color = 'm', alpha = 0.5, label = 'actual', bins=7)
ax.hist(pred_final, color = 'c', alpha = 0.5, label = 'prediction', bins=7)
ax.yaxis.set_ticks(np.arange(0,11))
ax.legend(loc = 'best')
plt.show()

# %%
# Plot of Actual Sales values and Predicted sales values
plt.plot(sales_data, color='b',marker='o', label='Actual Sales of CocaCola')
plt.plot(pred_final, color='m',marker='x', label='Predicted Sales of CocaCola')

# Added titles and adjust dimensions
plt.title('Actual Sales values and Predicted sales')
plt.xlabel("Timeline")
plt.ylabel("Sales")
plt.legend()
plt.rcParams['figure.figsize'] = (10,8) 

plt.show()
